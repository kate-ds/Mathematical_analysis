# %% [markdown]
# ## Практическое задание к уроку 6

# %% [markdown]
# ### Домашнее задание по теме «Производные функций нескольких переменных».
#
# __1.__ Найти область определения функции:
#
# ### $$z = \sqrt{1 - x^3} + ln(y^2-1)$$

# %% [markdown]
# ### \begin{cases}
#    1 - x^3 \geqslant 0 , \\
#    y^2 -1 > 0
#  \end{cases}
#
# ### \begin{cases}
#    x^3 \leqslant 1 , \\
#    y^2 > 1
#  \end{cases}
#
# ### $D(x,y) :$
# ### \begin{cases}
#    x \leqslant 1 , \\
#    y \neq 1
#  \end{cases}

# %% [markdown]
# __2.__ Найти производные 1-го порядка функции:
# ### $$z = \Bigl(1 + \frac{lnx}{lny}\Bigr)^3 $$

# %% [markdown]
# ### $$z'_x = 3 \Bigl(1 + \frac{lnx}{lny}\Bigr)^2 \cdot \frac{1}{xlny}$$
# ### $$z'_y = 3 \Bigl(1 + \frac{lnx}{lny}\Bigr)^2 \cdot (-1)ln^{-2}y \cdot lnx \frac{1}{y} = 3 \Bigl(1 + \frac{lnx}{lny}\Bigr)^2 \cdot \frac{-lnx}{y\cdot ln^2y}$$

# %% [markdown]
# __3.__  Найти полный дифференциал функции в точке (1;1):
# ### $$z = \sqrt{2xy + cos{\frac{x}{y}}}$$

# %% [markdown]
# ### $$z'_x = \frac{1}{2}\Bigl(2xy + cos{\frac{x}{y}}\Bigr)^{-\frac{1}{2}} \cdot \Bigl(2y + \Bigl(-sin{\frac{x}{y}}\Bigr) \cdot \frac{1}{y} \Bigr) =\\= \Bigl(2xy + cos{\frac{x}{y}}\Bigr)^{-\frac{1}{2}} \cdot \Bigl(y - \frac{sin{\frac{x}{y}}}{2y}\Bigr)$$
#
# ### $$z'_y = \frac{1}{2}\Bigl(2xy + cos{\frac{x}{y}}\Bigr)^{-\frac{1}{2}} \cdot \Bigl(2x - sin{\frac{x}{y}} \cdot (-1) \cdot \frac{x}{y^2} \Bigr) =\\= \Bigl(2xy + cos{\frac{x}{y}}\Bigr)^{-\frac{1}{2}} \cdot \Bigl(x + \frac{sin{\frac{x}{y}}}{2y^2}\Bigr)$$
#
# ### $$dz = \Bigl(2xy + cos{\frac{x}{y}}\Bigr)^{-\frac{1}{2}} \cdot \Bigl(y - \frac{sin{\frac{x}{y}}}{2y}\Bigr)dx + \\ + \Bigl(2xy + cos{\frac{x}{y}}\Bigr)^{-\frac{1}{2}} \cdot \Bigl(x + \frac{sin{\frac{x}{y}}}{2y^2}\Bigr)dy$$
#
# ### $$dz(1; 1) = \Bigl(2 + cos1\Bigr)^{-\frac{1}{2}} \cdot \Bigl(1 - \frac{sin1}{2}\Bigr)dx +  \Bigl(2 + cos1\Bigr)^{-\frac{1}{2}} \cdot \Bigl(1 + \frac{sin1}{2}\Bigr)dy =\\= \frac{2 - sin1}{2\sqrt{2+cos1}}dx + \frac{2 + sin1}{2\sqrt{2+cos1}}dy$$

# %% [markdown]
# __4.__ Исследовать на экстремум функцию:
#
# ### $$z = x^2 + xy + y^2 - 6x - 9y$$

# %% [markdown]
# ### \begin{cases}
#    z'_x= 2x + y - 6 = 0  \\
#    z'_y= x + 2y - 9 = 0
#  \end{cases}
#
# ### \begin{cases}
#    y = 6 - 2x \\
#    x + 12 - 4x =  9
#  \end{cases}
#
# ### \begin{cases}
#    y = 4 \\
#    x  =  1
#  \end{cases}
#
# Одна стационарная точка $(1; 4)$
#
# ### $$z''_{xx} = 2$$
# ### $$z''_{yy} = 2$$
# ### $$z''_{xy} = 1$$
# ### $$z''_{yx} = 1$$
#
# Матрица Гёссе:
# ###  $$\begin{pmatrix}
# 2 & 1\\
# 1 & 2\\
# \end{pmatrix}$$
#
# ### $$\Delta_{1}=z''_{xx}=2 > 0$$
# ### $$\Delta_{2}=z''_{xx}\cdot z''_{yy}-(z''_{xy})^2 = 4 - 1^2 = 3 > 0$$
#
# Оба минора больше нуля, следовательно, точка $(1; 4)$ является точкой минимума

# %% [markdown]
# ### Практическое задание из методички

# %% [markdown]
# __1.__ Найти частные производные первого и второго порядка. Убедиться в равенстве смешанных производных.
# ### $$U=x^3+3xy^2+z^2-39x-36y+2z+26$$

# %% [markdown]
# ### $$U'_x = 3x^2 + 3y^2 -39$$
# ### $$U'_y = 6xy -36$$
# ### $$U'_z = 2z + 2$$
# ### $$U''_{xx} = 6x$$
# ### $$U''_{xy} = 6y$$
# ### $$U''_{xz} = 0$$
# ### $$U''_{yy} = 6x$$
# ### $$U''_{yx} = 6y$$
# ### $$U''_{yz} = 0$$
# ### $$U''_{zz} = 2$$
# ### $$U''_{zx} = 0$$
# ### $$U''_{zy} = 0$$
#
# ### $$U''_{xy} = U''_{yx} = 6y$$
# ### $$U''_{xz} = U''_{zx} = 0$$
# ### $$U''_{yz} = U''_{zy} = 0$$

# %% [markdown]
# __2.__ Найти частные производные первого и второго порядка. Убедиться в равенстве смешанных производных.
#
# ### $$U=\frac{256}{x}+\frac{x^2}{y}+\frac{y^2}{z}+z^2$$

# %% [markdown]
# ### $$U'_x = -\frac{256}{x^2} + \frac{2x}{y}$$
# ### $$U'_y = - \frac{x^2}{y^2} + \frac{2y}{z}$$
# ### $$U'_z = - \frac{y^2}{z^2} + 2z$$
# ### $$U''_{xx} = \frac{2 \cdot 256}{x^3} + \frac{2}{y}$$
# ### $$U''_{yy} = \frac{2x^2}{y^3} + \frac{2}{z}$$
# ### $$U''_{zz} = \frac{2y^2}{z^3} + 2$$
# ### $$U''_{xy} =  -\frac{2x}{y^2}$$
# ### $$U''_{yx} =  -\frac{2x}{y^2}$$
# ### $$U''_{xy} =  U''_{yx}$$
# ### $$U''_{xz} = 0$$
# ### $$U''_{zx} = 0$$
# ### $$U''_{xz} = U''_{zx}$$
# ### $$U''_{yz} = - \frac{2y}{z^2}$$
# ### $$U''_{zy} = - \frac{2y}{z^2}$$
# ### $$U''_{yz} = U''_{zy}$$

# %% [markdown]
# __3.__ Найти производную функции $U=x^2+y^2+z^2$ по направлению вектора $\overrightarrow{c}(-9,8,-12)$ в точке $M(8,-12,9)$

# %% [markdown]
# ### $$U'_{\overrightarrow{c}} = \overrightarrow{c_0} \cdot gradU$$
# ### $$|c| = \sqrt{(-9)^2 +8^2 + (-12)^2} = \sqrt{289} = 17$$
# ### $$\overrightarrow{c_0} = \Bigl(-\frac{9}{17}, \frac{8}{17}, -\frac{12}{17}\Bigr)$$
# ### $$U'_x = 2x$$
# ### $$U'_y = 2y$$
# ### $$U'_z = 2z$$
# ### $$gradU = (2x, 2y, 2z)$$
# ### $$gradU (8, -12, 9) = (16, -24, 18)$$
# ### $$U'_{\overrightarrow{c}} = \Bigl(-\frac{9}{17}, \frac{8}{17}, -\frac{12}{17}\Bigr) \cdot (16, -24, 18) = - \frac{144}{17} - \frac{192}{17} - \frac{216}{17} = -\frac{552}{17}$$

# %% [markdown]
# __4.__ Найти производную функции $U=e^{x^2+y^2+z^2}$ по направлению вектора $\overrightarrow{c}(4,-13,-16)$ в точке $L(-16,4,-13)$

# %% [markdown]
# ### $$U'_{\overrightarrow{c}} = \overrightarrow{c_0} \cdot gradU$$
# ### $$|c| = \sqrt{(4)^2 +(-13)^2 + (-16)^2} = \sqrt{441} = 21$$
# ### $$\overrightarrow{c_0} = \Bigl(\frac{4}{21}, -\frac{13}{21}, -\frac{16}{21}\Bigr)$$
# ### $$U'_x = 2x\cdot e^{x^2+y^2+z^2}$$
# ### $$U'_y = 2y\cdot e^{x^2+y^2+z^2}$$
# ### $$U'_z = 2z\cdot e^{x^2+y^2+z^2}$$
# ### $$gradU = (2x\cdot e^{x^2+y^2+z^2}, 2y\cdot e^{x^2+y^2+z^2}, 2z\cdot e^{x^2+y^2+z^2})$$
# ### $$gradU (-16, 4, -13) = (-32\cdot e^{(-16)^2+4^2+(-13)^2}, 8\cdot e^{(-16)^2+4^2+(-13)^2}, -26\cdot e^{(-16)^2+4^2+(-13)^2}) = (-32e^{256+16+169}, 8e^{441}, -26e^{441}) = (-32e^{441}, 8e^{441}, -26e^{441})$$
# ### $$U'_{\overrightarrow{c}} = \Bigl(\frac{4}{21}, -\frac{13}{21}, -\frac{16}{21}\Bigr) \cdot (-32e^{441}, 8e^{441}, -26e^{441}) = e^{441} (\frac{4 \cdot (-32)}{21} + \frac{(-13) \cdot 8}{21} + \frac{(-16) \cdot (-26)}{21}) = e^{441} \frac{-128 -104 + 416}{21} = e^{441} \frac{-128 -104 + 416}{21} = e^{441} \frac{184}{21}$$

# %% [markdown]
# __5*.__ Найти производную функции $U=\log_{21}(x^2+y^2+z^2)$ в точке $F(-19,8,-4)$ по самому быстрому направлению.

# %% [markdown]
# ### $$U'_{gradU} = grad{U_0} \cdot gradU$$
#
# ### $$U'_x = \frac{2x}{ln21\cdot (x^2+y^2+z^2)}$$
# ### $$U'_y = \frac{2y}{ln21\cdot (x^2+y^2+z^2)}$$
# ### $$U'_z = \frac{2z}{ln21\cdot (x^2+y^2+z^2)}$$
# ### $$gradU = (\frac{2x}{ln21\cdot (x^2+y^2+z^2)}, \frac{2y}{ln21\cdot (x^2+y^2+z^2)}, \frac{2z}{ln21\cdot (x^2+y^2+z^2)})$$
#
# ### $$gradU (-19, 8, -4) = (\frac{-38}{ln21\cdot ((-19)^2+8^2+(-4)^2)}, \frac{16}{ln21\cdot (361+64+16)}, \frac{-8}{ln21\cdot 441}) = (\frac{-38}{441\cdot ln21}, \frac{16}{441\cdot ln21}, \frac{-8}{441\cdot ln21})$$
#
# ### $$|gradU| = \sqrt{\frac{(-38)^2 + 16^2 + (-8)^2}{(441\cdot ln21)^2}} = \sqrt{\frac{1444 + 256 + 64}{(441\cdot ln21)^2}} = \frac{\sqrt{1764}}{441\cdot ln21} = \frac{42}{441\cdot ln21}$$
#
#
# ### $$grad{U_0} = \frac{gradU}{|gradU|} = (\frac{-38 \cdot 441\cdot ln21}{42 \cdot 441\cdot ln21}, \frac{16 \cdot 441\cdot ln21}{42 \cdot 441\cdot ln21}, \frac{-8 \cdot 441\cdot ln21}{42 \cdot 441\cdot ln21}) = (-\frac{38}{42}, \frac{16}{42}, -\frac{8}{42}) = (-\frac{19}{21}, \frac{8}{21}, -\frac{4}{21})$$
#
# ### $$U'_{gradU} =(-\frac{19}{21}, \frac{8}{21}, -\frac{4}{21}) \cdot (\frac{-38}{441\cdot ln21}, \frac{16}{441\cdot ln21}, \frac{-8}{441\cdot ln21}) = \frac{38 \cdot 19 + 8 \cdot 16 + 8 \cdot 4}{21 \cdot 441\cdot ln21} = \frac{722 + 128 + 32}{21 \cdot 441\cdot ln21} = \frac{882}{21 \cdot 441\cdot ln21} = \frac{2}{21 \cdot ln21}$$

# %% [markdown]
# __6.__ Исследовать на экстремум функцию:
#
# ### $$U=x^2y+\frac{1}{3}y^3+2x^2+3y^2-1$$

# %% [markdown]
# ### \begin{cases}
#    U'_x= 2xy + 4x = 0  \\
#    U'_y= x^2 + y^2 +6y = 0
#  \end{cases}
#
# ### \begin{cases}
#    2x(y + 2) = 0  \\
#    x^2 + y^2 +6y = 0
#  \end{cases}
#
# ### $x = 0$ или $y = -2$
# ### 1. $$x = 0 \Rightarrow y^2 + 6y = 0 \Rightarrow y(y+6) = 0$$
# При $x = 0$  - 2 точки: $(0, 0)$, $(0, -6)$
# ### 2. $y = -2 \Rightarrow x^2 + 4 - 12 = 0 \Rightarrow x^2 = 8$
# При $y = -2$  - тоже 2 точки: $(2\sqrt{2}, -2)$, $(-2\sqrt{2}, -2)$
# Всего 4 стационарных точки. Составим матрицу Гёссе:
#
# ### $$U''_{xx} = 2y + 4$$
# ### $$U''_{yy} = 2y + 6$$
# ### $$U''_{xy} = 2x$$
# ### $$U''_{yx} = 2x$$
#
# ###  $$\begin{pmatrix}
# 2y + 6 & 2x\\
# 2x & 2y + 4\\
# \end{pmatrix}$$
#
# ### $$\Delta_{1}=2y + 6$$
# ### $$\Delta_{2}=(2y + 6)\cdot (2y + 4) - 4x^2 = 4y^2 + 8y + 12y + 24 - 4y^2 = 20y + 24$$
#
# 1. Для точки $(0, 0)$:
# ### $$\Delta_{1}= 6$$
# ### $$\Delta_{2}= 24$$
# Оба минора больше нуля, следовательно, точка $(0; 0)$ является точкой минимума
#
# 2. Для точки $(0, -6)$:
# ### $$\Delta_{1}= -6$$
# ### $$\Delta_{2}= -96$$
# Оба минора меньше нуля, следовательно, точка $(0; -6)$ является седловой точкой
#
# 3. Для точек  $(2\sqrt{2}, -2)$ и $(-2\sqrt{2}, -2)$:
# ### $$\Delta_{1}= 2$$
# ### $$\Delta_{2}= -16$$
# Первый минор положительный, второй - отрицательный, следовательно, обе точки - $(2\sqrt{2}, -2)$ и $(-2\sqrt{2}, -2)$ являются седловыми

# %% [markdown]
# __7*.__ Исследовать на экстремум функцию:
#
# ### $$U=e^{-\frac{x}{2}}\cdot(x^2+y^2)$$

# %% [markdown]
# ### \begin{cases}
#    U'_x= -\frac{1}{2}e^{-\frac{x}{2}}\cdot (x^2 + y^2) + e^{-\frac{x}{2}} \cdot 2x = 0  \\
#    U'_y= 2ye^{-\frac{x}{2}} = 0
#  \end{cases}
#
# ### \begin{cases}
#    e^{-\frac{x}{2}}(-\frac{1}{2}\cdot (x^2 + y^2) + 2x) = 0  \\
#    2ye^{-\frac{x}{2}} = 0
#  \end{cases}
#
# Так как $e^{-\frac{x}{2}} \neq 0$, можем разделить оба уравнения на эту часть:
#
# ### \begin{cases}
#    -\frac{1}{2}\cdot (x^2 + y^2) + 2x = 0  \\
#    2y = 0
#  \end{cases}
#
# ### $$y = 0 \Rightarrow x = 0, x = 4$$
# При $y = 0$  - 2 стационарные точки: $(0, 0)$, $(4, 0)$. Составим матрицу Гёссе:
#
# ### $$U''_{xx} = -\frac{1}{2}e^{-\frac{x}{2}}(2x - \frac{x^2}{2} - \frac{y^2}{2}) + e^{-\frac{x}{2}}(2 - x) = e^{-\frac{x}{2}} (\frac{x^2}{4} - 2x + \frac{y^2}{4} + 2)$$
# ### $$U''_{yy} = 2e^{-\frac{x}{2}}$$
# ### $$U''_{xy} = -2y\frac{e^{-\frac{x}{2}}}{2} = -ye^{-\frac{x}{2}}$$
# ### $$U''_{yx} = 2ye^{-\frac{x}{2}}\frac{-1}{2} = -ye^{-\frac{x}{2}}$$
#
# ###  $$\begin{pmatrix}
# 2e^{-\frac{x}{2}} & -ye^{-\frac{x}{2}}\\
# -ye^{-\frac{x}{2}} & e^{-\frac{x}{2}} (\frac{x^2}{4} - 2x + \frac{y^2}{4} + 2)\\
# \end{pmatrix}$$
#
# ### $$\Delta_{1}=2e^{-\frac{x}{2}} > 0$$
# ### $$\Delta_{2}=(2e^{-\frac{x}{2}})\cdot (e^{-\frac{x}{2}} (\frac{x^2}{4} - 2x + \frac{y^2}{4} + 2)) - (-ye^{-\frac{x}{2}})^2 = 4y^2 + 8y + 12y + 24 - 4y^2 = 20y + 24$$
#
# 1. Для точки $(0, 0)$:
# ### $$\Delta_{1} > 0$$
# ### $$\Delta_{2}= 1(0 - 0 - 0 + 4) > 0$$
# Оба минора больше нуля, следовательно, точка $(0; 0)$ является точкой минимума
#
# 2. Для точки $(4, 0)$:
# ### $$\Delta_{1} > 0$$
# ### $$\Delta_{2}= e^{-4}(8 - 0 - 16 + 4) = -4e^{-4} < 0$$
# Первый минор положительный, второй - отрицательный, следовательно, точка $(4, 0)$ является седловой

# %% [markdown]
# __8**.__ С помощью метода наименьших квадратов (МНК) подобрать значения параметров $a$ и $b$ для сигмоидальной функции $$y=\frac{1}{1+e^{-(ax+b)}}$$
#
# по заданному распределению. Построить график.
